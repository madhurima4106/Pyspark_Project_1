# %%
data=[('Alice','Badminton,Tennis'),('Bob','Tennis,Cricket'),('Jullie','Cricket,Carroms')]
schema=['name','hobbies']
df=spark.createDataFrame(data,schema)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>hobbies</th></tr></thead><tbody><tr><td>Alice</td><td>Badminton,Tennis</td></tr><tr><td>Bob</td><td>Tennis,Cricket</td></tr><tr><td>Jullie</td><td>Cricket,Carroms</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import  *
from pyspark.sql.window import  *

# %%
df1=df.select(df.name,explode(split(df.hobbies,',')).alias('hobbies'))
display(df1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>hobbies</th></tr></thead><tbody><tr><td>Alice</td><td>Badminton</td></tr><tr><td>Alice</td><td>Tennis</td></tr><tr><td>Bob</td><td>Tennis</td></tr><tr><td>Bob</td><td>Cricket</td></tr><tr><td>Jullie</td><td>Cricket</td></tr><tr><td>Jullie</td><td>Carroms</td></tr></tbody></table></div>

# %%
data=[('Goa','','AP'),('','AP',None),(None,'','BLR')]
schema=['city1','city2','city3']
df=spark.createDataFrame(data,schema)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city1</th><th>city2</th><th>city3</th></tr></thead><tbody><tr><td>Goa</td><td></td><td>AP</td></tr><tr><td></td><td>AP</td><td>null</td></tr><tr><td>null</td><td></td><td>BLR</td></tr></tbody></table></div>

# %%
df=df.withColumn('new',coalesce(
    (when(df.city1=='',None).otherwise(df.city1)),
    (when(df.city2=='',None).otherwise(df.city2)),
    (when(df.city3=='',None).otherwise(df.city3))
    )
)
display(df.select(df.new))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>new</th></tr></thead><tbody><tr><td>Goa</td></tr><tr><td>AP</td></tr><tr><td>BLR</td></tr></tbody></table></div>

# %%
data=[(1,'Steve'),(2,'David'),(3,'Aryan')]
schema=['Student_id','Student_name']
df=spark.createDataFrame(data,schema)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Student_id</th><th>Student_name</th></tr></thead><tbody><tr><td>1</td><td>Steve</td></tr><tr><td>2</td><td>David</td></tr><tr><td>3</td><td>Aryan</td></tr></tbody></table></div>

# %%
data=[(1,'Pyspark',90),(1,'Sql',100),(2,'Sql',70),(2,'Pyspark',60),(3,'Sql',30),(3,'Pyspark',20)]
schema=['Student_id','Subject_name','Marks']
df1=spark.createDataFrame(data,schema)
display(df1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Student_id</th><th>Subject_name</th><th>Marks</th></tr></thead><tbody><tr><td>1</td><td>Pyspark</td><td>90</td></tr><tr><td>1</td><td>Sql</td><td>100</td></tr><tr><td>2</td><td>Sql</td><td>70</td></tr><tr><td>2</td><td>Pyspark</td><td>60</td></tr><tr><td>3</td><td>Sql</td><td>30</td></tr><tr><td>3</td><td>Pyspark</td><td>20</td></tr></tbody></table></div>

# %%
df2=df.join(df1,df.Student_id==df1.Student_id,"inner").drop(df1.Student_id)
df3=df2.select('*').groupBy(df2.Student_id,df2.Student_name).agg((sum('Marks')/count('*')).alias('Percentage'))
df4=df3.select('*',when(df3.Percentage>=70,'Distinction').
                   when((df3.Percentage<=70) & (df3.Percentage>=60),'First Class').
                   when((df3.Percentage<=60) & (df3.Percentage>=50),'Second Class').
                   when((df3.Percentage<=50) & (df3.Percentage>=40),'Third Class').
                   otherwise('Fail')
               )
display(df4)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Student_id</th><th>Student_name</th><th>Percentage</th><th>CASE WHEN (Percentage >= 70) THEN Distinction WHEN ((Percentage <= 70) AND (Percentage >= 60)) THEN First Class WHEN ((Percentage <= 60) AND (Percentage >= 50)) THEN Second Class WHEN ((Percentage <= 50) AND (Percentage >= 40)) THEN Third Class ELSE Fail END</th></tr></thead><tbody><tr><td>1</td><td>Steve</td><td>95.0</td><td>Distinction</td></tr><tr><td>2</td><td>David</td><td>65.0</td><td>First Class</td></tr><tr><td>3</td><td>Aryan</td><td>25.0</td><td>Fail</td></tr></tbody></table></div>

# %%
data=[(1,'A',1000,'IT'),(2,'B',1500,'IT'),(3,'C',2500,'IT'),(4,'D',3000,'HR'),(5,'E',2000,'HR'),(6,'F',2000,'HR'),(7,'G',4000,'Sales'),(8,'H',4000,'Sales'),(9,'I',1000,'Sales'),(10,'J',2000,'Sales')]
schema=['EMPID','EMPNAME','SALARY','DEPARTMENT']
df=spark.createDataFrame(data,schema)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>EMPID</th><th>EMPNAME</th><th>SALARY</th><th>DEPARTMENT</th></tr></thead><tbody><tr><td>1</td><td>A</td><td>1000</td><td>IT</td></tr><tr><td>2</td><td>B</td><td>1500</td><td>IT</td></tr><tr><td>3</td><td>C</td><td>2500</td><td>IT</td></tr><tr><td>4</td><td>D</td><td>3000</td><td>HR</td></tr><tr><td>5</td><td>E</td><td>2000</td><td>HR</td></tr><tr><td>6</td><td>F</td><td>2000</td><td>HR</td></tr><tr><td>7</td><td>G</td><td>4000</td><td>Sales</td></tr><tr><td>8</td><td>H</td><td>4000</td><td>Sales</td></tr><tr><td>9</td><td>I</td><td>1000</td><td>Sales</td></tr><tr><td>10</td><td>J</td><td>2000</td><td>Sales</td></tr></tbody></table></div>

# %%
df1=df.select('*',(dense_rank().over(Window().partitionBy(df.DEPARTMENT).orderBy(df.SALARY.desc())).alias('Rank')))
df2=df1.filter(df1.Rank==1).drop(df1.Rank)
display(df2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>EMPID</th><th>EMPNAME</th><th>SALARY</th><th>DEPARTMENT</th></tr></thead><tbody><tr><td>4</td><td>D</td><td>3000</td><td>HR</td></tr><tr><td>3</td><td>C</td><td>2500</td><td>IT</td></tr><tr><td>7</td><td>G</td><td>4000</td><td>Sales</td></tr><tr><td>8</td><td>H</td><td>4000</td><td>Sales</td></tr></tbody></table></div>

# %%
data=[(1,'IT'),(2,'Sales')]
schema=['DeptID','DeptName']
df=spark.createDataFrame(data,schema)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>DeptID</th><th>DeptName</th></tr></thead><tbody><tr><td>1</td><td>IT</td></tr><tr><td>2</td><td>Sales</td></tr></tbody></table></div>

# %%
data=[(100,'Raj',None,1,'01-05-23',50000),(200,'Venki',100,1,'13-04-23',4000),(200,'Venki',100,1,'01-04-23',4500),(200,'Venki',100,1,'14-05-23',4020)]
schema=['EmpID','EmpName','MgrID','DeptID','Sal_Date','Sal']
df1=spark.createDataFrame(data,schema)
df2=spark.createDataFrame(data,schema)
display(df1)
display(df2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>EmpID</th><th>EmpName</th><th>MgrID</th><th>DeptID</th><th>Sal_Date</th><th>Sal</th></tr></thead><tbody><tr><td>100</td><td>Raj</td><td>null</td><td>1</td><td>01-05-23</td><td>50000</td></tr><tr><td>200</td><td>Venki</td><td>100</td><td>1</td><td>13-04-23</td><td>4000</td></tr><tr><td>200</td><td>Venki</td><td>100</td><td>1</td><td>01-04-23</td><td>4500</td></tr><tr><td>200</td><td>Venki</td><td>100</td><td>1</td><td>14-05-23</td><td>4020</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>EmpID</th><th>EmpName</th><th>MgrID</th><th>DeptID</th><th>Sal_Date</th><th>Sal</th></tr></thead><tbody><tr><td>100</td><td>Raj</td><td>null</td><td>1</td><td>01-05-23</td><td>50000</td></tr><tr><td>200</td><td>Venki</td><td>100</td><td>1</td><td>13-04-23</td><td>4000</td></tr><tr><td>200</td><td>Venki</td><td>100</td><td>1</td><td>01-04-23</td><td>4500</td></tr><tr><td>200</td><td>Venki</td><td>100</td><td>1</td><td>14-05-23</td><td>4020</td></tr></tbody></table></div>

# %%
df3=df1.join(df2,df1.MgrID==df2.EmpID,'left').drop(df2.EmpID,df1.MgrID,df2.MgrID,df2.DeptID,df2.Sal_Date,df2.Sal).select(df1.EmpID,df1.EmpName,df1.DeptID,df1.Sal_Date,df2.EmpName.alias('ManagerName'),df1.Sal)
df3=df3.select('EmpID','EmpName','DeptID',to_date(df3.Sal_Date,'dd-MM-yy').alias('Sal_Date'),'ManagerName','Sal')
df3=df3.select('*',year(df3.Sal_Date).alias('Salary_Year'),month(df3.Sal_Date).alias('Salary_Month'))
df4=df.join(df3,df.DeptID==df3.DeptID,'inner')
df4=df4.select('*').groupBy(df4.EmpName,df4.DeptName,df4.ManagerName,df4.EmpName,df4.Salary_Year,df4.Salary_Month).sum('Sal')
display(df4)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>EmpName</th><th>DeptName</th><th>ManagerName</th><th>EmpName</th><th>Salary_Year</th><th>Salary_Month</th><th>sum(Sal)</th></tr></thead><tbody><tr><td>Raj</td><td>IT</td><td>null</td><td>Raj</td><td>2023</td><td>5</td><td>50000</td></tr><tr><td>Venki</td><td>IT</td><td>Raj</td><td>Venki</td><td>2023</td><td>4</td><td>8500</td></tr><tr><td>Venki</td><td>IT</td><td>Raj</td><td>Venki</td><td>2023</td><td>5</td><td>4020</td></tr></tbody></table></div>

# %%
df=spark.read.option('header',True).csv('/FileStore/tables/products_2000000.csv')

# %%
df.rdd.getNumPartitions()
# Out:
# Out[3]: 8

# %%
df1=df.select(spark_partition_id().alias('Partyid')).groupBy('Partyid').count()
display(df1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Partyid</th><th>count</th></tr></thead><tbody><tr><td>0</td><td>254648</td></tr><tr><td>1</td><td>253913</td></tr><tr><td>2</td><td>253849</td></tr><tr><td>3</td><td>253764</td></tr><tr><td>4</td><td>252412</td></tr><tr><td>5</td><td>252328</td></tr><tr><td>6</td><td>252279</td></tr><tr><td>7</td><td>226807</td></tr></tbody></table></div>
